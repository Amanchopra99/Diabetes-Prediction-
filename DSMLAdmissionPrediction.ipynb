# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7ba72a64-d8ca-40d8-8f90-4d62a89dad0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ba72a64-d8ca-40d8-8f90-4d62a89dad0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
admit = pd.read_csv('Admission_Predict.csv')

# %%
admit.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
admit.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %%
admit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
admit.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332         0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398         0.810351
# ...

# %%
sns.heatmap(admit.corr(),annot=True)
# Out:
# <Axes: >

# %%
admit.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
y=admit['Chance of Admit']
x=admit.drop(['Serial No.','Chance of Admit','Research'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2529)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x.shape
# Out:
# (500, 6)

# %%
y.shape
# Out:
# (500,)

# %%
x_train.shape
# Out:
# (150, 6)

# %%
y_train.shape
# Out:
# (150,)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0.71892142, 0.83986182, 0.70651765, 0.73464775, 0.79621038,
#        0.5127415 , 0.72146319, 0.48955396, 0.65915755, 0.53842179,
#        0.62691816, 0.846972  , 0.61310922, 0.98974278, 0.65540355,
#        0.72701592, 0.47934285, 0.78168817, 0.77351555, 0.73624357,
#        0.98874581, 0.76491674, 0.95941267, 0.82191312, 0.8296068 ,
#        0.6141514 , 0.74240687, 0.72680224, 0.69260853, 0.88154086,
#        0.92302443, 0.64700696, 0.64456323, 0.81605386, 0.86966771,
#        0.74774265, 0.49208384, 0.54479615, 0.75998905, 0.76387186,
#        0.96958303, 0.78657437, 0.78807441, 0.93135599, 0.63621745,
#        0.52330568, 0.84400863, 0.61433917, 0.45370122, 0.85482667,
#        0.79005604, 0.55832553, 0.59700458, 0.77220854, 0.75847191,
#        0.42990521, 0.87876452, 0.74371891, 0.85114597, 0.49338556,
#        0.56525816, 0.68805633, 0.60802446, 0.77258995, 0.56525118,
#        0.64135457, 0.66876459, 0.79216308, 0.63401768, 0.8562941 ,
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.07075843466381017

# %%
import numpy as np
features = []
n = 6
for i in range(0, n):
    ele = int(input('GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	'))
    features.append(ele)

my_array= np.array(features)
print(features)


feature = np.array(my_array)

feature= feature.reshape(1,6)

user_pred = model.predict(feature)

print('Chance of Admission is',user_pred)
# Out:
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	432
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	433
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	6
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	4
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	8
# GRE, Score,	TOEFL, Score,	University, Rating,	SOP,	LOR,	CGPA	9
# [432, 433, 6, 4, 8, 9]
# Chance of Admission is [1.19282558]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
